# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name":['Abhay','anoop','uma'],
    "marks":[30,55,98],
    "city":['bhayander','kushinagar','kushinagar'],
    "age":[20,21,22]
}

# %%
df = pd.DataFrame(dict1)
df
# Out:
#     name  marks        city  age
# 0  Abhay     30   bhayander   20
# 1  anoop     55  kushinagar   21
# 2    uma     98  kushinagar   22

# %%
df.to_csv('bhaicharaontop.csv',index=True)

# %%
df.to_csv('bhaicharaontop_index.csv',index=False)

# %%
df.head(2)
# Out:
#     name  marks        city  age
# 0  Abhay     30   bhayander   20
# 1  anoop     55  kushinagar   21

# %%
df.tail(2)
# Out:
#     name  marks        city  age
# 1  anoop     55  kushinagar   21
# 2    uma     98  kushinagar   22

# %%
df.describe()
# Out:
#            marks   age
# count   3.000000   3.0
# mean   61.000000  21.0
# std    34.394767   1.0
# min    30.000000  20.0
# 25%    42.500000  20.5
# 50%    55.000000  21.0
# 75%    76.500000  21.5
# max    98.000000  22.0

# %%
dict1['marks'][2]
# Out:
# 98

# %%
dict1['marks'][1]
# Out:
# 55

# %%
dict1['marks'][1]=101

# %%
dict1['marks'][1]
# Out:
# 101

# %%
df.to_csv('edit.csv')

# %%
df
# Out:
#           name  marks        city  age
# first    Abhay     30   bhayander   20
# secound  anoop     55  kushinagar   21
# third      uma     98  kushinagar   22

# %%
df.index=['first','secound','third']

# %%
df
# Out:
#           name  marks        city  age
# first    Abhay     30   bhayander   20
# secound  anoop     55  kushinagar   21
# third      uma     98  kushinagar   22

# %%
ser = pd.Series(np.random.rand(50))

# %%
ser
# Out:
# 0     0.670760
# 1     0.068686
# 2     0.602814
# 3     0.739984
# 4     0.686841
# 5     0.589276
# 6     0.273884
# 7     0.231681
# 8     0.538385
# 9     0.735553
# 10    0.878939
# 11    0.155489
# 12    0.274161
# 13    0.634128
# 14    0.714388
# 15    0.242468
# 16    0.896307
# 17    0.778933
# 18    0.671685
# 19    0.539869
# 20    0.960646
# 21    0.948650
# 22    0.364588
# 23    0.881683
# 24    0.319995
# 25    0.001476
# 26    0.125628
# 27    0.692765
# 28    0.170550
# 29    0.833310
# 30    0.147761
# 31    0.554880
# 32    0.504846
# 33    0.712951
# 34    0.901087
# 35    0.407806
# 36    0.915987
# 37    0.274720
# 38    0.639218
# 39    0.494215
# 40    0.332162
# 41    0.806672
# 42    0.916795
# 43    0.257587
# 44    0.743063
# 45    0.435367
# 46    0.934224
# 47    0.211983
# 48    0.761576
# 49    0.688816
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf=pd.DataFrame(np.random.rand(334,7),index=np.arange(334))

# %%
df1=pd.DataFrame(newdf)

# %%
df1
# Out:
#             0         1         2         3         4         5         6
# 0    0.178055  0.240248  0.044012  0.628712  0.308382  0.685469  0.937270
# 1    0.842416  0.006249  0.029287  0.953330  0.536457  0.785743  0.824785
# 2    0.654957  0.253535  0.834936  0.256123  0.216081  0.799045  0.954611
# 3    0.549538  0.924555  0.769317  0.143917  0.147219  0.723534  0.875991
# 4    0.990653  0.537987  0.942654  0.159077  0.059024  0.968339  0.337892
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.762290  0.754002  0.431462  0.973777  0.707646  0.685415  0.314369
# 330  0.796958  0.397064  0.494894  0.105299  0.995645  0.237193  0.929119
# 331  0.344094  0.455526  0.164911  0.010651  0.955038  0.599277  0.753931
# 332  0.081558  0.660234  0.919063  0.829786  0.009433  0.880124  0.258434
# 333  0.041343  0.553661  0.984594  0.589938  0.921731  0.937755  0.976014
#
# [334 rows x 7 columns]

# %%
df1.to_csv('random.csv')

# %%
df1.head(5)
# Out:
#           0         1         2         3         4         5         6
# 0  0.178055  0.240248  0.044012  0.628712  0.308382  0.685469  0.937270
# 1  0.842416  0.006249  0.029287  0.953330  0.536457  0.785743  0.824785
# 2  0.654957  0.253535  0.834936  0.256123  0.216081  0.799045  0.954611
# 3  0.549538  0.924555  0.769317  0.143917  0.147219  0.723534  0.875991
# 4  0.990653  0.537987  0.942654  0.159077  0.059024  0.968339  0.337892

# %%
df1.tail(45)
# Out:
#             0         1         2         3         4         5         6
# 289  0.568935  0.541830  0.059394  0.036163  0.459056  0.884098  0.376865
# 290  0.895238  0.611548  0.260480  0.567225  0.812859  0.412720  0.464041
# 291  0.143203  0.702348  0.396901  0.665617  0.685026  0.499985  0.314329
# 292  0.102168  0.943673  0.865021  0.533605  0.098873  0.172385  0.252664
# 293  0.291177  0.263534  0.419977  0.904369  0.293138  0.172320  0.256166
# 294  0.515954  0.208872  0.175134  0.084488  0.453431  0.825026  0.703992
# 295  0.100653  0.919979  0.959207  0.555355  0.652710  0.782191  0.722501
#
# [334 rows x 7 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4         5         6
# 0       0.3  0.240248  0.044012  0.628712  0.308382  0.685469  0.937270
# 1  0.842416  0.006249  0.029287  0.953330  0.536457  0.785743  0.824785
# 2  0.654957  0.253535  0.834936  0.256123  0.216081  0.799045  0.954611
# 3  0.549538  0.924555  0.769317  0.143917  0.147219  0.723534  0.875991
# 4  0.990653  0.537987  0.942654  0.159077  0.059024  0.968339  0.337892

# %%
newdf[0]
# Out:
# 0           0.3
# 1      0.842416
# 2      0.654957
# 3      0.549538
# 4      0.990653
#          ...
# 329     0.76229
# 330    0.796958
# 331    0.344094
# 332    0.081558
# 333    0.041343
# Name: 0, Length: 334, dtype: object

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
newdf2=newdf

# %%
newdf2[0][0]=7688

# %%
newdf
# Out:
#             0         1         2         3         4         5         6
# 0        7688  0.240248  0.044012  0.628712  0.308382  0.685469  0.937270
# 1    0.842416  0.006249  0.029287  0.953330  0.536457  0.785743  0.824785
# 2    0.654957  0.253535  0.834936  0.256123  0.216081  0.799045  0.954611
# 3    0.549538  0.924555  0.769317  0.143917  0.147219  0.723534  0.875991
# 4    0.990653  0.537987  0.942654  0.159077  0.059024  0.968339  0.337892
# ..        ...       ...       ...       ...       ...       ...       ...
# 329   0.76229  0.754002  0.431462  0.973777  0.707646  0.685415  0.314369
# 330  0.796958  0.397064  0.494894  0.105299  0.995645  0.237193  0.929119
# 331  0.344094  0.455526  0.164911  0.010651  0.955038  0.599277  0.753931
# 332  0.081558  0.660234  0.919063  0.829786  0.009433  0.880124  0.258434
# 333  0.041343  0.553661  0.984594  0.589938  0.921731  0.937755  0.976014
#
# [334 rows x 7 columns]

# %%
newdf2=newdf.copy()

# %%
newdf2[0][0]=7847
# Out:
# C:\Users\abhay\AppData\Local\Temp\ipykernel_6952\3044889777.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf2[0][0]=7847
# C:\Users\abhay\AppData\Local\Temp\ipykernel_6952\3044889777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0]=7847

# %%
newdf
# Out:
#             0         1         2         3         4         5         6
# 0        7688  0.240248  0.044012  0.628712  0.308382  0.685469  0.937270
# 1    0.842416  0.006249  0.029287  0.953330  0.536457  0.785743  0.824785
# 2    0.654957  0.253535  0.834936  0.256123  0.216081  0.799045  0.954611
# 3    0.549538  0.924555  0.769317  0.143917  0.147219  0.723534  0.875991
# 4    0.990653  0.537987  0.942654  0.159077  0.059024  0.968339  0.337892
# ..        ...       ...       ...       ...       ...       ...       ...
# 329   0.76229  0.754002  0.431462  0.973777  0.707646  0.685415  0.314369
# 330  0.796958  0.397064  0.494894  0.105299  0.995645  0.237193  0.929119
# 331  0.344094  0.455526  0.164911  0.010651  0.955038  0.599277  0.753931
# 332  0.081558  0.660234  0.919063  0.829786  0.009433  0.880124  0.258434
# 333  0.041343  0.553661  0.984594  0.589938  0.921731  0.937755  0.976014
#
# [334 rows x 7 columns]

# %%
newdf2
# Out:
#             0         1         2         3         4         5         6
# 0        7847  0.240248  0.044012  0.628712  0.308382  0.685469  0.937270
# 1    0.842416  0.006249  0.029287  0.953330  0.536457  0.785743  0.824785
# 2    0.654957  0.253535  0.834936  0.256123  0.216081  0.799045  0.954611
# 3    0.549538  0.924555  0.769317  0.143917  0.147219  0.723534  0.875991
# 4    0.990653  0.537987  0.942654  0.159077  0.059024  0.968339  0.337892
# ..        ...       ...       ...       ...       ...       ...       ...
# 329   0.76229  0.754002  0.431462  0.973777  0.707646  0.685415  0.314369
# 330  0.796958  0.397064  0.494894  0.105299  0.995645  0.237193  0.929119
# 331  0.344094  0.455526  0.164911  0.010651  0.955038  0.599277  0.753931
# 332  0.081558  0.660234  0.919063  0.829786  0.009433  0.880124  0.258434
# 333  0.041343  0.553661  0.984594  0.589938  0.921731  0.937755  0.976014
#
# [334 rows x 7 columns]

# %%
newdf.loc[0,0]=789

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4         5         6
# 0       789  0.240248  0.044012  0.628712  0.308382  0.685469  0.937270
# 1  0.842416  0.006249  0.029287  0.953330  0.536457  0.785743  0.824785

# %%
newdf.columns=list(ABCDE)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1105], line 1
# ----> 1 newdf.columns=list(ABCDE)
#
# NameError: name 'ABCDE' is not defined

# %%
newdf.columns=list('ABCDE')
# Out:
# ---------------------------------------
# ValueErrorTraceback (most recent call last)
# Cell In[78], line 1
# ----> 1 newdf.columns=list('ABCDE')
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 5 elements

# %%
newdf.columns=list("ABCDE")
# Out:
# ---------------------------------------
# ValueErrorTraceback (most recent call last)
# Cell In[79], line 1
# ----> 1 newdf.columns=list("ABCDE")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 7 elements, new values have 5 elements

# %%
newdf
# Out:
#             0         1         2         3         4         5         6
# 0         789  0.732255  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  0.413924  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  0.597789  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  0.756801  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  0.922058  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.342848  0.633102  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  0.454005  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  0.563573  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  0.150265  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  0.505396  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf.columns = list("ABCDEFG")

# %%
newdf
# Out:
#             A         B         C         D         E         F         G
# 0         789  0.732255  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  0.413924  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  0.597789  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  0.756801  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  0.922058  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.342848  0.633102  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  0.454005  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  0.563573  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  0.150265  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  0.505396  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E         F         G
# 0       789  0.732255  0.351324  0.659387  0.601363  0.566645  0.197575
# 1  0.496064  0.413924  0.382995  0.479833  0.344376  0.826340  0.164167

# %%
newdf.loc[0,0]=343

# %%
newdf
# Out:
#             A         B         C         D         E         F         G  \
# 0         789  0.732255  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  0.413924  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  0.597789  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  0.756801  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  0.922058  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.342848  0.633102  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  0.454005  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  0.563573  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  0.150265  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  0.505396  0.056516  0.444042  0.137280  0.735201  0.418280
#
#          0
# 0    343.0
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 329    NaN
# 330    NaN
# 331    NaN
# 332    NaN
# 333    NaN
#
# [334 rows x 8 columns]

# %%
newdf.loc[0,B]=3433434
# Out:
# ---------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[86], line 1
# ----> 1 newdf.loc[0,B]=3433434
#
# NameError: name 'B' is not defined

# %%
newdf.loc[0,B]=3433434
# Out:
# ---------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[87], line 1
# ----> 1 newdf.loc[0,B]=3433434
#
# NameError: name 'B' is not defined

# %%
newdf.loc[0,'B']=3433434

# %%
newdf
# Out:
#             A             B         C         D         E         F         G  \
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
#          0
# 0    343.0
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 329    NaN
# 330    NaN
# 331    NaN
# 332    NaN
# 333    NaN
#
# [334 rows x 8 columns]

# %%
newdf.drop(0)
# Out:
#             A         B         C         D         E         F         G   0
# 1    0.496064  0.413924  0.382995  0.479833  0.344376  0.826340  0.164167 NaN
# 2    0.956946  0.597789  0.368882  0.466570  0.446012  0.924404  0.188137 NaN
# 3    0.780838  0.756801  0.498901  0.876915  0.110383  0.795265  0.545934 NaN
# 4    0.757952  0.922058  0.536396  0.658299  0.189329  0.745976  0.494504 NaN
# 5    0.820049  0.728288  0.160382  0.053314  0.260068  0.297298  0.255434 NaN
# ..        ...       ...       ...       ...       ...       ...       ...  ..
# 329  0.342848  0.633102  0.336135  0.458489  0.283372  0.468894  0.495477 NaN
# 330   0.73182  0.454005  0.281243  0.466615  0.056260  0.973836  0.177644 NaN
# 331  0.117758  0.563573  0.070537  0.964707  0.446820  0.828148  0.615651 NaN
# 332  0.582776  0.150265  0.030585  0.915223  0.553152  0.106969  0.754742 NaN
# 333  0.015527  0.505396  0.056516  0.444042  0.137280  0.735201  0.418280 NaN
#
# [333 rows x 8 columns]

# %%
newdf
# Out:
#             A             B         C         D         E         F         G  \
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
#          0
# 0    343.0
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 329    NaN
# 330    NaN
# 331    NaN
# 332    NaN
# 333    NaN
#
# [334 rows x 8 columns]

# %%
newdf.drop(0,axis=1)
# Out:
#             A             B         C         D         E         F         G
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf=newdf.drop(0,axis=1)

# %%
newdf
# Out:
#             A             B         C         D         E         F         G
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf.loc[1,2],['c','d']
# Out:
# ---------------------------------------
# KeyErrorTraceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyErrorTraceback (most recent call last)
# Cell In[95], line 1
# ----> 1 newdf.loc[1,2],['c','d']
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4214, in DataFrame._get_value(self, index, col, takeable)
#    4211     series = self._ixs(col, axis=1)
#    4212     return series._values[index]
# -> 4214 series = self._get_item_cache(col)
#    4215 engine = self.index._engine
#    4217 if not isinstance(self.index, MultiIndex):
#    4218     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4219     #  results if our categories are integers that dont match our codes
#    4220     # IntervalIndex: IntervalTree has no get_loc
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4638, in DataFrame._get_item_cache(self, item)
#    4633 res = cache.get(item)
#    4634 if res is None:
#    4635     # All places that call _get_item_cache have unique columns,
#    4636     #  pending resolution of GH#33047
# -> 4638     loc = self.columns.get_loc(item)
#    4639     res = self._ixs(loc, axis=1)
#    4641     cache[item] = res
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 2

# %%
newdf.loc[[1,2],['B','C']]
# Out:
#           B         C
# 1  0.413924  0.382995
# 2  0.597789  0.368882

# %%
newdf.loc[:,['B','C']]
# Out:
#                 B         C
# 0    3.433434e+06  0.351324
# 1    4.139239e-01  0.382995
# 2    5.977894e-01  0.368882
# 3    7.568014e-01  0.498901
# 4    9.220584e-01  0.536396
# ..            ...       ...
# 329  6.331019e-01  0.336135
# 330  4.540052e-01  0.281243
# 331  5.635734e-01  0.070537
# 332  1.502649e-01  0.030585
# 333  5.053964e-01  0.056516
#
# [334 rows x 2 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E         F         G
# 1  0.496064  0.413924  0.382995  0.479833  0.344376  0.826340  0.164167
# 2  0.956946  0.597789  0.368882  0.466570  0.446012  0.924404  0.188137

# %%
newdf.loc[newdf[0]<0.3]
# Out:
# ---------------------------------------
# KeyErrorTraceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyErrorTraceback (most recent call last)
# Cell In[99], line 1
# ----> 1 newdf.loc[newdf[0]<0.3]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 0

# %%
newdf.loc[newdf['A']<0.3]
# Out:
#             A         B         C         D         E         F         G
# 8     0.28509  0.612416  0.789871  0.376900  0.562869  0.528353  0.787734
# 14   0.154709  0.709595  0.414937  0.128026  0.662712  0.874566  0.778027
# 17    0.03655  0.855725  0.753284  0.644496  0.669113  0.258129  0.073138
# 19   0.229383  0.231811  0.091871  0.250413  0.442254  0.742826  0.116186
# 22   0.024691  0.545538  0.057153  0.035479  0.095290  0.286606  0.975273
# ..        ...       ...       ...       ...       ...       ...       ...
# 323  0.079498  0.808822  0.322192  0.208437  0.356719  0.931184  0.906558
# 324  0.011871  0.452114  0.047271  0.860469  0.793315  0.253253  0.477313
# 328  0.060934  0.235814  0.390894  0.215766  0.329086  0.970755  0.808384
# 331  0.117758  0.563573  0.070537  0.964707  0.446820  0.828148  0.615651
# 333  0.015527  0.505396  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [106 rows x 7 columns]

# %%
wdf.loc[(newdf['A']<0.3)]
# Out:
# ---------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[101], line 1
# ----> 1 wdf.loc[(newdf['A']<0.3)]
#
# NameError: name 'wdf' is not defined

# %%
newdf.loc[(newdf['A']<0.3)]
# Out:
#             A         B         C         D         E         F         G
# 8     0.28509  0.612416  0.789871  0.376900  0.562869  0.528353  0.787734
# 14   0.154709  0.709595  0.414937  0.128026  0.662712  0.874566  0.778027
# 17    0.03655  0.855725  0.753284  0.644496  0.669113  0.258129  0.073138
# 19   0.229383  0.231811  0.091871  0.250413  0.442254  0.742826  0.116186
# 22   0.024691  0.545538  0.057153  0.035479  0.095290  0.286606  0.975273
# ..        ...       ...       ...       ...       ...       ...       ...
# 323  0.079498  0.808822  0.322192  0.208437  0.356719  0.931184  0.906558
# 324  0.011871  0.452114  0.047271  0.860469  0.793315  0.253253  0.477313
# 328  0.060934  0.235814  0.390894  0.215766  0.329086  0.970755  0.808384
# 331  0.117758  0.563573  0.070537  0.964707  0.446820  0.828148  0.615651
# 333  0.015527  0.505396  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [106 rows x 7 columns]

# %%
newdf.loc[(newdf['A']<0.01)]
# Out:
#             A         B         C         D         E         F         G
# 200  0.005232  0.381011  0.706832  0.229070  0.221099  0.946771  0.085440
# 219  0.005515  0.247583  0.046656  0.870088  0.179330  0.426296  0.758585

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>01)]
# Out:
#   Cell In[104], line 1
#     newdf.loc[(newdf['A']<0.3) & (newdf['C']>01)]
#                                              ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.2)]
# Out:
#             A         B         C         D         E         F         G
# 8     0.28509  0.612416  0.789871  0.376900  0.562869  0.528353  0.787734
# 14   0.154709  0.709595  0.414937  0.128026  0.662712  0.874566  0.778027
# 17    0.03655  0.855725  0.753284  0.644496  0.669113  0.258129  0.073138
# 23   0.181349  0.063451  0.239249  0.454745  0.467048  0.728813  0.698111
# 28   0.037691  0.957728  0.967358  0.792439  0.404522  0.042040  0.623094
# ..        ...       ...       ...       ...       ...       ...       ...
# 311  0.191428  0.471996  0.105071  0.851347  0.450607  0.790587  0.726434
# 313  0.154809  0.081811  0.264733  0.079910  0.945605  0.036450  0.335372
# 316  0.133249  0.682099  0.616490  0.865512  0.037157  0.960690  0.498285
# 323  0.079498  0.808822  0.322192  0.208437  0.356719  0.931184  0.906558
# 328  0.060934  0.235814  0.390894  0.215766  0.329086  0.970755  0.808384
#
# [94 rows x 7 columns]

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.2)]
# Out:
#             A         B         C         D         E         F         G
# 8     0.28509  0.612416  0.789871  0.376900  0.562869  0.528353  0.787734
# 14   0.154709  0.709595  0.414937  0.128026  0.662712  0.874566  0.778027
# 17    0.03655  0.855725  0.753284  0.644496  0.669113  0.258129  0.073138
# 23   0.181349  0.063451  0.239249  0.454745  0.467048  0.728813  0.698111
# 28   0.037691  0.957728  0.967358  0.792439  0.404522  0.042040  0.623094
# ..        ...       ...       ...       ...       ...       ...       ...
# 307  0.166786  0.623204  0.604674  0.834876  0.741455  0.801596  0.476892
# 313  0.154809  0.081811  0.264733  0.079910  0.945605  0.036450  0.335372
# 316  0.133249  0.682099  0.616490  0.865512  0.037157  0.960690  0.498285
# 323  0.079498  0.808822  0.322192  0.208437  0.356719  0.931184  0.906558
# 328  0.060934  0.235814  0.390894  0.215766  0.329086  0.970755  0.808384
#
# [83 rows x 7 columns]

# %%
newdf.head(2)
# Out:
#           A             B         C         D         E         F         G
# 0       789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1  0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167

# %%
newdf.iloc[[0,4]
# Out:
#   Cell In[108], line 1
#     newdf.iloc[[0,4]
#                     ^
# _IncompleteInputError: incomplete input

# %%
newdf.iloc[[0,4]
# Out:
#   Cell In[109], line 1
#     newdf.iloc[[0,4]
#                     ^
# _IncompleteInputError: incomplete input

# %%
newdf.loc[[0,4]
# Out:
#   Cell In[110], line 1
#     newdf.loc[[0,4]
#                    ^
# _IncompleteInputError: incomplete input

# %%
newdf
# Out:
#             A             B         C         D         E         F         G
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf.iloc[0,2]
# Out:
# np.float64(0.3513237255164716)

# %%
newdf.iloc[0,4]
# Out:
# np.float64(0.6013630047741328)

# %%
newdf.iloc[[7,5],[1,2]]
# Out:
#           B         C
# 7  0.691048  0.117182
# 5  0.728288  0.160382

# %%
newd.head(3)
# Out:
# ---------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[117], line 1
# ----> 1 newd.head(3)
#
# NameError: name 'newd' is not defined

# %%
newdf.head(3)
# Out:
#           A             B         C         D         E         F         G
# 0       789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1  0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2  0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E         F         G
# 1    0.496064  0.413924  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  0.597789  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  0.756801  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  0.922058  0.536396  0.658299  0.189329  0.745976  0.494504
# 5    0.820049  0.728288  0.160382  0.053314  0.260068  0.297298  0.255434
# ..        ...       ...       ...       ...       ...       ...       ...
# 329  0.342848  0.633102  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  0.454005  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  0.563573  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  0.150265  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  0.505396  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [333 rows x 7 columns]

# %%
newdf.drop([2,2])
# Out:
#             A             B         C         D         E         F         G
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# 5    0.820049  7.282881e-01  0.160382  0.053314  0.260068  0.297298  0.255434
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [333 rows x 7 columns]

# %%
newdf
# Out:
#             A             B         C         D         E         F         G
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf[2,'b']
# Out:
# ---------------------------------------
# KeyErrorTraceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (2, 'b')
#
# The above exception was the direct cause of the following exception:
#
# KeyErrorTraceback (most recent call last)
# Cell In[123], line 1
# ----> 1 newdf[2,'b']
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: (2, 'b')

# %%
newdf[2,'B']
# Out:
# ---------------------------------------
# KeyErrorTraceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (2, 'B')
#
# The above exception was the direct cause of the following exception:
#
# KeyErrorTraceback (most recent call last)
# Cell In[124], line 1
# ----> 1 newdf[2,'B']
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: (2, 'B')

# %%
newdf['B']
# Out:
# 0      3.433434e+06
# 1      4.139239e-01
# 2      5.977894e-01
# 3      7.568014e-01
# 4      9.220584e-01
#            ...
# 329    6.331019e-01
# 330    4.540052e-01
# 331    5.635734e-01
# 332    1.502649e-01
# 333    5.053964e-01
# Name: B, Length: 334, dtype: float64

# %%
newdf
# Out:
#             A             B         C         D         E         F         G
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf
# Out:
#             A             B         C         D         E         F         G
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf.drop['B',axis=1]
# Out:
#   Cell In[128], line 1
#     newdf.drop['B',axis=1]
#                    ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
newdf.drop('C',axis=1)
# Out:
#             A             B         D         E         F         G
# 0         789  3.433434e+06  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 6 columns]

# %%
newdf.drop('B',axis=1)
# Out:
#             A         C         D         E         F         G
# 0         789  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...       ...       ...       ...       ...       ...
# 329  0.342848  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 6 columns]

# %%
newdf
# Out:
#             A             B         C         D         E         F         G
# 0         789  3.433434e+06  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  4.139239e-01  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  5.977894e-01  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  7.568014e-01  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  9.220584e-01  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...           ...       ...       ...       ...       ...       ...
# 329  0.342848  6.331019e-01  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  4.540052e-01  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  5.635734e-01  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  1.502649e-01  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  5.053964e-01  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf.drop('B',axis=1,inplace=True)

# %%
newdf
# Out:
#             A         C         D         E         F         G
# 0         789  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...       ...       ...       ...       ...       ...
# 329  0.342848  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 6 columns]

# %%
newdf.reset_index()
# Out:
#      index         A         C         D         E         F         G
# 0        0       789  0.351324  0.659387  0.601363  0.566645  0.197575
# 1        1  0.496064  0.382995  0.479833  0.344376  0.826340  0.164167
# 2        2  0.956946  0.368882  0.466570  0.446012  0.924404  0.188137
# 3        3  0.780838  0.498901  0.876915  0.110383  0.795265  0.545934
# 4        4  0.757952  0.536396  0.658299  0.189329  0.745976  0.494504
# ..     ...       ...       ...       ...       ...       ...       ...
# 329    329  0.342848  0.336135  0.458489  0.283372  0.468894  0.495477
# 330    330   0.73182  0.281243  0.466615  0.056260  0.973836  0.177644
# 331    331  0.117758  0.070537  0.964707  0.446820  0.828148  0.615651
# 332    332  0.582776  0.030585  0.915223  0.553152  0.106969  0.754742
# 333    333  0.015527  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 7 columns]

# %%
newdf.reset_index(drop=True)
# Out:
#             A         C         D         E         F         G
# 0         789  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...       ...       ...       ...       ...       ...
# 329  0.342848  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 6 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf
# Out:
#             A         C         D         E         F         G
# 0         789  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    0.496064  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    0.956946  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    0.780838  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    0.757952  0.536396  0.658299  0.189329  0.745976  0.494504
# ..        ...       ...       ...       ...       ...       ...
# 329  0.342848  0.336135  0.458489  0.283372  0.468894  0.495477
# 330   0.73182  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  0.117758  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  0.582776  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  0.015527  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 6 columns]

# %%
newdf.head(3)
# Out:
#           A         C         D         E         F         G
# 0       789  0.351324  0.659387  0.601363  0.566645  0.197575
# 1  0.496064  0.382995  0.479833  0.344376  0.826340  0.164167
# 2  0.956946  0.368882  0.466570  0.446012  0.924404  0.188137

# %%
newdf['A']=None

# %%
newdf
# Out:
#         A         C         D         E         F         G
# 0    None  0.351324  0.659387  0.601363  0.566645  0.197575
# 1    None  0.382995  0.479833  0.344376  0.826340  0.164167
# 2    None  0.368882  0.466570  0.446012  0.924404  0.188137
# 3    None  0.498901  0.876915  0.110383  0.795265  0.545934
# 4    None  0.536396  0.658299  0.189329  0.745976  0.494504
# ..    ...       ...       ...       ...       ...       ...
# 329  None  0.336135  0.458489  0.283372  0.468894  0.495477
# 330  None  0.281243  0.466615  0.056260  0.973836  0.177644
# 331  None  0.070537  0.964707  0.446820  0.828148  0.615651
# 332  None  0.030585  0.915223  0.553152  0.106969  0.754742
# 333  None  0.056516  0.444042  0.137280  0.735201  0.418280
#
# [334 rows x 6 columns]

# %%
newdf['B']=isnull()
# Out:
# ---------------------------------------
# NameErrorTraceback (most recent call last)
# Cell In[148], line 1
# ----> 1 newdf['B']=isnull()
#
# NameError: name 'isnull' is not defined

# %%
newdf['B'].isnull()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1106], line 1
# ----> 1 newdf['B'].isnull()
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'B'

# %%
newdf.loc[:,'A']=23

# %%
newdf
# Out:
#             0         1         2         3         4         5         6   A
# 0         789  0.240248  0.044012  0.628712  0.308382  0.685469  0.937270  23
# 1    0.842416  0.006249  0.029287  0.953330  0.536457  0.785743  0.824785  23
# 2    0.654957  0.253535  0.834936  0.256123  0.216081  0.799045  0.954611  23
# 3    0.549538  0.924555  0.769317  0.143917  0.147219  0.723534  0.875991  23
# 4    0.990653  0.537987  0.942654  0.159077  0.059024  0.968339  0.337892  23
# ..        ...       ...       ...       ...       ...       ...       ...  ..
# 329   0.76229  0.754002  0.431462  0.973777  0.707646  0.685415  0.314369  23
# 330  0.796958  0.397064  0.494894  0.105299  0.995645  0.237193  0.929119  23
# 331  0.344094  0.455526  0.164911  0.010651  0.955038  0.599277  0.753931  23
# 332  0.081558  0.660234  0.919063  0.829786  0.009433  0.880124  0.258434  23
# 333  0.041343  0.553661  0.984594  0.589938  0.921731  0.937755  0.976014  23
#
# [334 rows x 8 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4         5         6   A
# 0       789  0.240248  0.044012  0.628712  0.308382  0.685469  0.937270  23
# 1  0.842416  0.006249  0.029287  0.953330  0.536457  0.785743  0.824785  23
# 2  0.654957  0.253535  0.834936  0.256123  0.216081  0.799045  0.954611  23
# 3  0.549538  0.924555  0.769317  0.143917  0.147219  0.723534  0.875991  23
# 4  0.990653  0.537987  0.942654  0.159077  0.059024  0.968339  0.337892  23

# %%
df=pd.DataFrame({
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
})

# %%
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.dropna()
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.head()
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df.dropna(how='all',axis=1)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
df=pd.DataFrame({
  "calories": [420, 420, 390],
  "duration": [420, 40, 45]
})

# %%
df
# Out:
#    calories  duration
# 0       420       420
# 1       420        40
# 2       390        45

# %%
df.drop_duplicates(subset=['calories'],keep=False)
# Out:
#    calories  duration
# 2       390        45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   calories  3 non-null      int64
#  1   duration  3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0 bytes

# %%
df['name'].value
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\abhay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1120], line 1
# ----> 1 df['name'].value
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\abhay\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
df['name'].value_count
# Out:
# ---------------------------------------
# KeyErrorTraceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'name'
#
# The above exception was the direct cause of the following exception:
#
# KeyErrorTraceback (most recent call last)
# Cell In[169], line 1
# ----> 1 df['name'].value_count
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'name'

# %%
df['calories'].value_counts(dropna=True)
# Out:
# calories
# 420    2
# 390    1
# Name: count, dtype: int64

# %%
newdf
